# %%
original_audio_file = "sample_kaze.mp4"

# %%
# ファイルパスの定義
import os
from pathlib import Path
audio_name = original_audio_file.split(".")[0]
original_audio_path = original_audio = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'original', original_audio_file))
vocal_audio_path = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals.mp3'))
tuned_vocal_path = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals_tuned.mp3'))
for file in [original_audio_path, vocal_audio_path]:
    if not file.exists():
        raise FileNotFoundError(f"{file} not Found")
output_midi_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals_transcribed.mid')

# %%
from audio_separator.separator import Separator

# Initialize the Separator class (with optional configuration properties, below)
separator = Separator()

# Load a machine learning model (if unspecified, defaults to 'model_mel_band_roformer_ep_3005_sdr_11.4360.ckpt')
separator.load_model("UVR_MDXNET_KARA.onnx")

# Perform the separation on specific audio files without reloading the model
output_files = separator.separate(original_audio_path)

print(f"Separation complete! Output file(s): {' '.join(output_files)}")
# Out:
# 2026-02-11 11:55:46,339 - INFO - separator - Separator version 0.18.0 instantiating with output_dir: None, output_format: WAV
# 2026-02-11 11:55:46,339 - INFO - separator - Output directory not specified. Using current working directory.
# 2026-02-11 11:55:46,340 - INFO - separator - Operating System: Darwin Darwin Kernel Version 25.0.0: Wed Sep 17 21:42:08 PDT 2025; root:xnu-12377.1.9~141/RELEASE_ARM64_T8132
# 2026-02-11 11:55:46,340 - INFO - separator - System: Darwin Node: yamashitakouheis-MacBook-Air.local Release: 25.0.0 Machine: arm64 Proc: arm
# 2026-02-11 11:55:46,340 - INFO - separator - Python Version: 3.11.14
# 2026-02-11 11:55:46,340 - INFO - separator - PyTorch Version: 2.8.0
# 2026-02-11 11:55:46,521 - INFO - separator - FFmpeg installed: ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
# 2026-02-11 11:55:46,522 - INFO - separator - ONNX Runtime CPU package installed with version: 1.19.2
# 2026-02-11 11:55:46,523 - INFO - separator - Apple Silicon MPS/CoreML is available in Torch and processor is ARM, setting Torch device to MPS
# 2026-02-11 11:55:46,523 - INFO - separator - ONNXruntime has CoreMLExecutionProvider available, enabling acceleration
# 2026-02-11 11:55:46,525 - INFO - separator - Loading model UVR_MDXNET_KARA.onnx...
# 2026-02-11 11:55:47,302 - INFO - separator - Load model duration: 00:00:00
# 2026-02-11 11:55:47,303 - INFO - separator - Starting separation process for audio_file_path: /Users/kpome/github/solfege-gen/data/original/sample_kaze.mp4
# 100%|██████████| 16/16 [00:05<00:00,  2.76it/s]
# 100%|██████████| 12/12 [00:00<00:00, 20.19it/s]
# 2026-02-11 11:55:53,783 - INFO - mdx_separator - Saving Instrumental stem to sample_kaze_(Instrumental)_UVR_MDXNET_KARA.wav...
# 2026-02-11 11:55:53,791 - INFO - mdx_separator - Saving Vocals stem to sample_kaze_(Vocals)_UVR_MDXNET_KARA.wav...
# 2026-02-11 11:55:53,883 - INFO - common_separator - Clearing input audio file paths, sources and stems...
# 2026-02-11 11:55:53,883 - INFO - separator - Separation duration: 00:00:06
# Separation complete! Output file(s): sample_kaze_(Instrumental)_UVR_MDXNET_KARA.wav sample_kaze_(Vocals)_UVR_MDXNET_KARA.wav

# %%
from audio_separator.separator import Separator

# Initialize the Separator class (with optional configuration properties, below)
separator = Separator()

# Load a machine learning model (if unspecified, defaults to 'model_mel_band_roformer_ep_3005_sdr_11.4360.ckpt')
separator.load_model("UVR-DeEcho-DeReverb.pth")

# Perform the separation on specific audio files without reloading the model
output_files = separator.separate(output_files[1])

print(f"Separation complete! Output file(s): {' '.join(output_files)}")
# Out:
# 2026-02-11 11:55:53,888 - INFO - separator - Separator version 0.18.0 instantiating with output_dir: None, output_format: WAV
# 2026-02-11 11:55:53,888 - INFO - separator - Output directory not specified. Using current working directory.
# 2026-02-11 11:55:53,889 - INFO - separator - Operating System: Darwin Darwin Kernel Version 25.0.0: Wed Sep 17 21:42:08 PDT 2025; root:xnu-12377.1.9~141/RELEASE_ARM64_T8132
# 2026-02-11 11:55:53,889 - INFO - separator - System: Darwin Node: yamashitakouheis-MacBook-Air.local Release: 25.0.0 Machine: arm64 Proc: arm
# 2026-02-11 11:55:53,889 - INFO - separator - Python Version: 3.11.14
# 2026-02-11 11:55:53,890 - INFO - separator - PyTorch Version: 2.8.0
# 2026-02-11 11:55:53,945 - INFO - separator - FFmpeg installed: ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
# 2026-02-11 11:55:53,947 - INFO - separator - ONNX Runtime CPU package installed with version: 1.19.2
# 2026-02-11 11:55:53,947 - INFO - separator - Apple Silicon MPS/CoreML is available in Torch and processor is ARM, setting Torch device to MPS
# 2026-02-11 11:55:53,948 - INFO - separator - ONNXruntime has CoreMLExecutionProvider available, enabling acceleration
# 2026-02-11 11:55:53,991 - INFO - separator - Loading model UVR-DeEcho-DeReverb.pth...
# 2026-02-11 11:55:54,010 - INFO - vr_separator - VR Separator initialisation complete
# 2026-02-11 11:55:54,011 - INFO - separator - Load model duration: 00:00:00
# 2026-02-11 11:55:54,011 - INFO - separator - Starting separation process for audio_file_path: sample_kaze_(Vocals)_UVR_MDXNET_KARA.wav
# 100%|██████████| 4/4 [00:00<00:00, 29.37it/s]
# 100%|██████████| 17/17 [00:00<00:00, 609428.79it/s]
# 100%|██████████| 2/2 [00:28<00:00, 14.12s/it]
# 2026-02-11 11:56:25,287 - INFO - vr_separator - Saving No Reverb stem to sample_kaze_(Vocals)_UVR_MDXNET_KARA_(No Reverb)_UVR-DeEcho-DeReverb.wav...
# 2026-02-11 11:56:25,709 - INFO - vr_separator - Saving Instrumental stem to sample_kaze_(Vocals)_UVR_MDXNET_KARA_(Instrumental)_UVR-DeEcho-DeReverb.wav...
# 2026-02-11 11:56:26,753 - INFO - common_separator - Clearing input audio file paths, sources and stems...
# 2026-02-11 11:56:26,755 - INFO - separator - Separation duration: 00:00:32
# Separation complete! Output file(s): sample_kaze_(Vocals)_UVR_MDXNET_KARA_(No Reverb)_UVR-DeEcho-DeReverb.wav sample_kaze_(Vocals)_UVR_MDXNET_KARA_(Instrumental)_UVR-DeEcho-DeReverb.wav
