# %%
original_audio_file = "ztmy_shortened.mp4"

# %%
# ファイルパスの定義
import os
from pathlib import Path
audio_name = original_audio_file.split(".")[0]
original_audio_path = original_audio = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'original', original_audio_file))
vocal_audio_path = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals.mp3'))
tuned_vocal_path = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals_tuned.mp3'))
demucs_processed_path = Path(os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}'))
pre_separated_audio_path = Path(os.path.join(demucs_processed_path, "vocals.mp3"))
for file in [original_audio_path, vocal_audio_path]:
    if not file.exists():
        raise FileNotFoundError(f"{file} not Found")
output_midi_path = os.path.join(os.path.dirname(os.getcwd()), 'data', 'processed', f'htdemucs/{audio_name}/vocals_transcribed.mid')

# %%
from audio_separator.separator import Separator

# Initialize the Separator class (with optional configuration properties, below)
separator = Separator()

# Load a machine learning model (if unspecified, defaults to 'model_mel_band_roformer_ep_3005_sdr_11.4360.ckpt')
separator.load_model("UVR_MDXNET_KARA.onnx")

# Perform the separation on specific audio files without reloading the model
output_files = separator.separate(original_audio_path)

print(f"Separation complete! Output file(s): {' '.join(output_files)}")
# Out:
# 2026-02-12 22:58:18,089 - INFO - separator - Separator version 0.18.0 instantiating with output_dir: None, output_format: WAV
# 2026-02-12 22:58:18,089 - INFO - separator - Output directory not specified. Using current working directory.
# 2026-02-12 22:58:18,090 - INFO - separator - Operating System: Darwin Darwin Kernel Version 25.0.0: Wed Sep 17 21:42:08 PDT 2025; root:xnu-12377.1.9~141/RELEASE_ARM64_T8132
# 2026-02-12 22:58:18,090 - INFO - separator - System: Darwin Node: yamashitakouheis-MacBook-Air.local Release: 25.0.0 Machine: arm64 Proc: arm
# 2026-02-12 22:58:18,091 - INFO - separator - Python Version: 3.11.14
# 2026-02-12 22:58:18,091 - INFO - separator - PyTorch Version: 2.8.0
# 2026-02-12 22:58:18,267 - INFO - separator - FFmpeg installed: ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
# 2026-02-12 22:58:18,270 - INFO - separator - ONNX Runtime CPU package installed with version: 1.19.2
# 2026-02-12 22:58:18,271 - INFO - separator - Apple Silicon MPS/CoreML is available in Torch and processor is ARM, setting Torch device to MPS
# 2026-02-12 22:58:18,271 - INFO - separator - ONNXruntime has CoreMLExecutionProvider available, enabling acceleration
# 2026-02-12 22:58:18,273 - INFO - separator - Loading model UVR_MDXNET_KARA.onnx...
# 2026-02-12 22:58:19,163 - INFO - separator - Load model duration: 00:00:00
# 2026-02-12 22:58:19,164 - INFO - separator - Starting separation process for audio_file_path: /Users/kpome/github/solfege-gen/data/original/ztmy_shortened.mp4
# 100%|██████████| 23/23 [00:08<00:00,  2.64it/s]
# 100%|██████████| 17/17 [00:00<00:00, 20.71it/s]
# 2026-02-12 22:58:28,846 - INFO - mdx_separator - Saving Instrumental stem to ztmy_shortened_(Instrumental)_UVR_MDXNET_KARA.wav...
# 2026-02-12 22:58:28,859 - INFO - mdx_separator - Saving Vocals stem to ztmy_shortened_(Vocals)_UVR_MDXNET_KARA.wav...
# 2026-02-12 22:58:28,934 - INFO - common_separator - Clearing input audio file paths, sources and stems...
# 2026-02-12 22:58:28,934 - INFO - separator - Separation duration: 00:00:09
# Separation complete! Output file(s): ztmy_shortened_(Instrumental)_UVR_MDXNET_KARA.wav ztmy_shortened_(Vocals)_UVR_MDXNET_KARA.wav

# %%
from audio_separator.separator import Separator

# Initialize the Separator class (with optional configuration properties, below)
separator = Separator()

# Load a machine learning model (if unspecified, defaults to 'model_mel_band_roformer_ep_3005_sdr_11.4360.ckpt')
separator.load_model("UVR-DeEcho-DeReverb.pth")

# Perform the separation on specific audio files without reloading the model
output_files = separator.separate(pre_separated_audio_path)

print(f"Separation complete! Output file(s): {' '.join(output_files)}")
# Out:
# 2026-02-15 11:39:08,614 - INFO - separator - Separator version 0.18.0 instantiating with output_dir: None, output_format: WAV
# 2026-02-15 11:39:08,614 - INFO - separator - Output directory not specified. Using current working directory.
# 2026-02-15 11:39:08,615 - INFO - separator - Operating System: Darwin Darwin Kernel Version 25.0.0: Wed Sep 17 21:42:08 PDT 2025; root:xnu-12377.1.9~141/RELEASE_ARM64_T8132
# 2026-02-15 11:39:08,615 - INFO - separator - System: Darwin Node: yamashitakouheis-MacBook-Air.local Release: 25.0.0 Machine: arm64 Proc: arm
# 2026-02-15 11:39:08,615 - INFO - separator - Python Version: 3.11.14
# 2026-02-15 11:39:08,615 - INFO - separator - PyTorch Version: 2.8.0
# 2026-02-15 11:39:08,650 - INFO - separator - FFmpeg installed: ffmpeg version 8.0.1 Copyright (c) 2000-2025 the FFmpeg developers
# 2026-02-15 11:39:08,651 - INFO - separator - ONNX Runtime CPU package installed with version: 1.19.2
# 2026-02-15 11:39:08,659 - INFO - separator - Apple Silicon MPS/CoreML is available in Torch and processor is ARM, setting Torch device to MPS
# 2026-02-15 11:39:08,659 - INFO - separator - ONNXruntime has CoreMLExecutionProvider available, enabling acceleration
# 2026-02-15 11:39:08,659 - INFO - separator - Loading model UVR-DeEcho-DeReverb.pth...
#  88%|████████▊ | 198M/224M [00:22<00:02, 9.37MiB/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       4 separator = Separator()
#       6 # Load a machine learning model (if unspecified, defaults to 'model_mel_band_roformer_ep_3005_sdr_11.4360.ckpt')
# ----> 7 separator.load_model("UVR-DeEcho-DeReverb.pth")
#       9 # Perform the separation on specific audio files without reloading the model
#      10 output_files = separator.separate(pre_separated_audio_path)
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/audio_separator/separator/separator.py:632, in Separator.load_model(self, model_filename)
#     629 load_model_start_time = time.perf_counter()
#     631 # Setting up the model path
# --> 632 model_filename, model_type, model_friendly_name, model_path, yaml_config_filename = self.download_model_files(model_filename)
#     633 model_name = model_filename.split(".")[0]
#     634 self.logger.debug(f"Model downloaded, friendly name: {model_friendly_name}, model_path: {model_path}")
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/audio_separator/separator/separator.py:422, in Separator.download_model_files(self, model_filename)
#     419 self.logger.debug(f"Single file model identified: {model_friendly_name}")
#     420 self.model_friendly_name = model_friendly_name
# --> 422 self.download_file_if_not_exists(f"{model_repo_url_prefix}/{model_filename}", model_path)
#     423 self.print_uvr_vip_message()
#     425 self.logger.debug(f"Returning path for single model file: {model_path}")
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/audio_separator/separator/separator.py:307, in Separator.download_file_if_not_exists(self, url, output_path)
#     304 progress_bar = tqdm(total=total_size_in_bytes, unit="iB", unit_scale=True)
#     306 with open(output_path, "wb") as f:
# --> 307     for chunk in response.iter_content(chunk_size=8192):
#     308         progress_bar.update(len(chunk))
#     309         f.write(chunk)
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/urllib3/response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)
#    1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File ~/github/solfege-gen/.venv/lib/python3.11/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/http/client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/.local/share/uv/python/cpython-3.11.14-macos-aarch64-none/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:
#  89%|████████▉ | 199M/224M [00:40<00:02, 9.37MiB/s]
